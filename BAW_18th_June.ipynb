# %%
# %matplotlib notebook
import skrf as rf
#rf.stylely()

# %%
from skrf import Network

A_init = Network('A_init.s1p')
A_postplasma = Network('A_postplasma.s1p')

B_init = Network('B_init.s1p')
B_postplasma = Network('B_postplasma.s1p')

C_init = Network('C_init.s1p')
C_postplasma = Network('C_postplasma.s1p')

D_init = Network('D_init.s1p')
D_postplasma = Network('D_postplasma.s1p')
#ring_slot.plot_s_smith()

# %%
A_init.plot_s_db()
A_postplasma.plot_s_db()

B_init.plot_s_db()
B_postplasma.plot_s_db()

C_init.plot_s_db()
C_postplasma.plot_s_db()

D_init.plot_s_db()
D_postplasma.plot_s_db()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
A_init.plot_z_mag()
A_postplasma.plot_z_mag()

B_init.plot_z_mag()
B_postplasma.plot_z_mag()

C_init.plot_z_mag()
C_postplasma.plot_z_mag()

D_init.plot_z_mag()
D_postplasma.plot_z_mag()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
A_init.plot_z_re()
A_postplasma.plot_z_re()

B_init.plot_z_re()
B_postplasma.plot_z_re()

C_init.plot_z_re()
C_postplasma.plot_z_re()

D_init.plot_z_re()
D_postplasma.plot_z_re()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
A_init.plot_z_im()
A_postplasma.plot_z_im()

B_init.plot_z_im()
B_postplasma.plot_z_im()

C_init.plot_z_im()
C_postplasma.plot_z_im()

D_init.plot_z_im()
D_postplasma.plot_z_im()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
A_init.plot_z_db()
A_postplasma.plot_z_db()

B_init.plot_z_db()
B_postplasma.plot_z_db()

C_init.plot_z_db()
C_postplasma.plot_z_db()

D_init.plot_z_db()
D_postplasma.plot_z_db()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
A_init.plot_y_im()
A_postplasma.plot_y_im()

B_init.plot_y_im()
B_postplasma.plot_y_im()

C_init.plot_y_im()
C_postplasma.plot_y_im()

D_init.plot_y_im()
D_postplasma.plot_y_im()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
A_init.plot_y_re()
A_postplasma.plot_y_re()

B_init.plot_y_re()
B_postplasma.plot_y_re()

C_init.plot_y_re()
C_postplasma.plot_y_re()

D_init.plot_y_re()
D_postplasma.plot_y_re()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
A_init.plot_y_db()
A_postplasma.plot_y_db()

B_init.plot_y_db()
B_postplasma.plot_y_db()

C_init.plot_y_db()
C_postplasma.plot_y_db()

D_init.plot_y_db()
D_postplasma.plot_y_db()
